# %% [markdown]
# <a href="https://colab.research.google.com/github/jlianacastillo/Analisis-Ubate/blob/main/analisisubate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analisis de Datos 1969 - 2023
# * Importacion de .csv (DataSet)

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# # Librerias
# * Importacion de librerias
# * Numpy
# * Pandas
# * Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sc
import seaborn as sns

# %% [markdown]
# # Precipitacion

# %% [markdown]
# * Carga de los datos con pandas

# %%
import pandas as pd

precipitacion = pd.read_csv('/content/drive/MyDrive/Precipitacion.csv')
precipitacion.head()
# Out:
#       CODIGO     AÑO  DIA ENE  FEB  MAR ABR  MAY   JUN  JUL  AGO   SEP   OCT  \
# 0  2401519.0  1966.0  1.0   0    0    0   0    0  19,5  2,3    0  13,5  23,4
# 1  2401519.0  1966.0  2.0   0    0  0,2   0    0  19,9    0  0,2   6,4     0
# 2  2401519.0  1966.0  3.0   0    0  1,6   0    0     0    0  0,8   0,5   0,9
# 3  2401519.0  1966.0  4.0   0    0  1,8   0  1,5     0    0  2,8     0     0
# 4  2401519.0  1966.0  5.0   0  0,3    0   0    0     0    0  0,2     0   0,4
#
#     NOV
# 0   0,5
# 1   4,5
# 2   3,6
# 3     0
# 4  13,4

# %% [markdown]
# # Tamano de precipitacion 24 hrs

# %%
precipitacion.shape
# Out:
# (1759, 14)

# %% [markdown]
# # Identificacion de columnas

# %%
precipitacion.columns
# Out:
# Index(['CODIGO', 'AÑO', 'DIA', 'ENE', 'FEB', 'MAR', 'ABR', 'MAY', 'JUN', 'JUL',
#        'AGO', 'SEP', 'OCT', 'NOV'],
#       dtype='object')

# %% [markdown]
# # Tipo de datos (datatype)

# %%
precipitacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1759 entries, 0 to 1758
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CODIGO  1705 non-null   float64
#  1   AÑO     1705 non-null   float64
#  2   DIA     1705 non-null   float64
#  3   ENE     1621 non-null   object
#  4   FEB     1530 non-null   object
#  5   MAR     1689 non-null   object
#  6   ABR     1649 non-null   object
#  7   MAY     1702 non-null   object
#  8   JUN     1608 non-null   object
#  9   JUL     1612 non-null   object
#  10  AGO     1608 non-null   object
#  11  SEP     1559 non-null   object
#  12  OCT     1630 non-null   object
#  13  NOV     1560 non-null   object
# dtypes: float64(3), object(11)
# memory usage: 192.5+ KB

# %% [markdown]
# # Minimo y maximo

# %%
precipitacion.describe()
# Out:
#           CODIGO          AÑO          DIA
# count     1705.0  1705.000000  1705.000000
# mean   2401519.0  1994.509091    16.000000
# std          0.0    17.121598     8.946896
# min    2401519.0  1966.000000     1.000000
# 25%    2401519.0  1979.000000     8.000000
# 50%    2401519.0  1995.000000    16.000000
# 75%    2401519.0  2010.000000    24.000000
# max    2401519.0  2023.000000    31.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['CODIGO'], **{})
# chart
# import numpy as np
# ...

# %% [markdown]
# # Grafica de bloxplot

# %%
precipitacion = np.random.RandomState(0).randn(100)
plt.boxplot(precipitacion)
plt.title("Boxplot precipitacion Datos 1969 - 2023")
plt.show()
